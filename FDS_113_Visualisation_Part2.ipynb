# %% [markdown]
# <a href="https://colab.research.google.com/github/Akellesh/DataScience_Course_library2023/blob/main/FDS_113_Visualisation_Part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Lib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use(['dark_background'])
import seaborn as sns
sns.set(color_codes = True)
import json

# %% [markdown]
# # Plotting the composition of Data

# %% [markdown]
# ## Static composition

# %% [markdown]
# ### Pie chart

# %%
p = sns.load_dataset('penguins')

# %%
p.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
p.groupby('species').count()
# Out:
#            island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# species
# Adelie        152             151            151                151
# Chinstrap      68              68             68                 68
# Gentoo        124             123            123                123
#
#            body_mass_g  sex
# species
# Adelie             151  146
# Chinstrap           68   68
# Gentoo             123  119

# %%
p.groupby('species')['species'].count() # looking at species columns itself so
# Out:
# species
# Adelie       152
# Chinstrap     68
# Gentoo       124
# Name: species, dtype: int64

# %%
c = p.groupby('species')['species'].count() # assigning to one variable to use for charts

# %%
plt.pie(c);
plt.show();

# %%
plt.pie(c, labels = c.index); # need to label the data
plt.show();

# %%
plt.pie(c, labels = c.index, autopct="%.2f%%"); #percentage distribution ploted
plt.show();

# %%
plt.pie(c, labels = c.index, autopct="%.2f%%",
        explode=[0,1,0]); # separate from actual circle for better visual
plt.show();

# %%
plt.pie(c, labels = c.index, autopct="%.2f%%",
        explode=[0,1,0], startangle=180); # angle can be changed
plt.show();

# %%
plt.pie(c, labels = c.index, autopct="%.2f%%",
        explode=[0,1,0], startangle=180, shadow=True); # gives little shadow appearance
plt.show();

# %%
plt.pie(np.random.randint(0,10,10));
plt.show();

# %% [markdown]
# ### Donut chart

# %%
plt.pie(np.random.randint(0,10,10), wedgeprops=dict(width = 0.3));
plt.show();

# %%
cmap = plt.get_cmap('Pastel1') # color is very light, we can go for different color
my_colors = cmap(np.arange(10))
plt.pie(np.random.randint(0,10,10),
        wedgeprops=dict(width = 0.4),
        colors=my_colors);
plt.show();

# %%
cmap = plt.get_cmap('Accent') # color is very light, we can go for different color
my_colors = cmap(np.arange(10))
plt.pie(np.random.randint(0,10,10),
        wedgeprops=dict(width = 0.4),
        colors=my_colors);
plt.show();

# %%
plt.pie(c, labels = c.index, autopct="%.2f%%",
        wedgeprops=dict(width=0.4)); # implemented for penguin dataset
plt.show();

# %%
c_i = p.groupby('island')['island'].count()

# %%
plt.pie(c, labels = c_i.index, autopct="%.2f%%",
        wedgeprops=dict(width=0.4)); # implemented for island penguin dataset
plt.show();

# %%
pd.crosstab(p.species,p.island)
# Out:
# island     Biscoe  Dream  Torgersen
# species
# Adelie         44     56         52
# Chinstrap       0     68          0
# Gentoo        124      0          0

# %%
c_d = pd.crosstab(p.species,p.island)

# %%
c_d = c_d.T

# %%
c_d
# Out:
# species    Adelie  Chinstrap  Gentoo
# island
# Biscoe         44          0     124
# Dream          56         68       0
# Torgersen      52          0       0

# %%
plt.pie(c_d.sum(axis=1),labels=c_d.index, radius =1,
        wedgeprops=dict(width=0.3));

# %%
plt.pie(c_d.sum(axis=1),labels=c_d.index, radius =1,
        wedgeprops=dict(width=0.3));
plt.pie(c_d.values.flatten(),radius=0.7,
        wedgeprops=dict(width=0.3));

# %%
cmap = plt.get_cmap('tab20c') # color is very light, we can go for different color
outer_colors = cmap(np.array([0,4,8]))
inner_colors = cmap(np.array([1,2,3,5,6,7,9,10,11]))

# %%
plt.pie(c_d.sum(axis=1),labels=c_d.index, radius =1, # still need to address inner label
        wedgeprops=dict(width=0.3),colors=outer_colors);
plt.pie(c_d.values.flatten(),radius=0.7,
        wedgeprops=dict(width=0.3),colors=inner_colors);

# %%
plt.pie(c_d.sum(axis=1),labels=c_d.index, radius =1,
        wedgeprops=dict(width=0.3),colors=outer_colors); # empty '' having 0 as value so
plt.pie(c_d.values.flatten(),radius=0.7,
        labels = ['A','','G','A','C','','A','',''],
        wedgeprops=dict(width=0.3),colors=inner_colors);

# %%
plt.pie(c_d.sum(axis=1),labels=c_d.index, radius =1,
        wedgeprops=dict(width=0.3),colors=outer_colors); # empty '' having 0 as value so
plt.pie(c_d.values.flatten(),radius=0.7,
        labels = ['A', '' , 'G' , 'A' , 'C' , '' , 'A' , '' , ''],
        wedgeprops=dict(width=0.3),colors=inner_colors,
        labeldistance=0.7);

# %%
cmap = plt.get_cmap('tab20b') # color is very light, we can go for different color
outer_colors = cmap(np.array([0,4,8]))
inner_colors = cmap(np.array([1,2,3,5,6,7,9,10,11]))

plt.pie(c_d.sum(axis=1),labels=c_d.index, radius =1,
        wedgeprops=dict(width=0.3),colors=outer_colors); # empty '' having 0 as value so
plt.pie(c_d.values.flatten(),radius=0.7,
        labels = ['A', '' , 'G' , 'A' , 'C' , '' , 'A' , '' , ''],
        wedgeprops=dict(width=0.3),colors=inner_colors,
        labeldistance=0.7);

# %% [markdown]
# ### Stacked Bar plot

# %%
url = 'https://api.covid19india.org/states_daily.json'
urllib.request.urlretrieve(url,'data.json')

with open('data.json') as f:
    data = json.load(f)
data = data['states_daily']
df = pd.json_normalize(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-1ef767878119> in <cell line: 2>()
#       1 url = 'https://api.covid19india.org/states_daily.json'
# ----> 2 urllib.request.urlretrieve(url,'data.json')
#       3
#       4 with open('data.json') as f:
#       5     data = json.load(f)
#
# NameError: name 'urllib' is not defined

# %%
df_ = df.tail(3)
df_.drop('date', axis=1,inplace=True)
df_.set_index('status',inplace=True)
df_ = df_.T
df_ = df_.apply(pd.to_numeric)
df_.drop('tt',inplace=True)

# %%
fig = plt.gcf();
fig.set_size_inches(15,6);
plt.bar(df_.index, df_.Confirmed, color='Orange');
plt.bar(df_.index, df_.Recovered, bottom=df_.Confirmed, color='Green');
plt.bar(df_.index, df_.Deceased, bottom=df_.Confirmed + df_.Recovered, color='Red')
plt.xticks(ratation=90);

for i, val in enumerate(df_.index):
    y = df_.loc[val].sum() + 100
    if y > 1000:
        x = i
        plt.text(x,y, str(y), ha="center");

# %% [markdown]
# ### Relative stacked bar plots

# %%
df_['Total'] = 0

# %%
df_['Total'] = df_.sum(axis=1)

# %%
df_.head()

# %%
df_['ConfirmedFraction'] = df_['Confirmed'] / df_['Total']
df_['RecoveredFraction'] = df_['Recovered'] / df_['Total']
df_['DeceasedFraction'] = df_['Deceased'] / df_['Total']

# %%
df_.head()

# %%
fig = plt.gcf();
fig.set_size_inches(15,6);
plt.bar(df_.index, df_.ConfirmedFraction, color='Orange');
plt.bar(df_.index, df_.RecoveredFraction, bottom=df_.ConfirmedFraction, color='Green');
plt.bar(df_.index, df_.DeceasedFraction, bottom=df_.ConfirmedFraction + df_.RecoveredFraction, color='Red')
plt.xticks(ratation=90);

# %%
df_ = df_.sort_values('ConfirmedFraction', ascending=False) # now we have sorted the values, so plot the abov again

# %%
fig = plt.gcf();
fig.set_size_inches(15,6);
plt.bar(df_.index, df_.ConfirmedFraction, color='Orange');
plt.bar(df_.index, df_.RecoveredFraction, bottom=df_.ConfirmedFraction, color='Green');
plt.bar(df_.index, df_.DeceasedFraction, bottom=df_.ConfirmedFraction + df_.RecoveredFraction, color='Red')
plt.xticks(ratation=90);

# %% [markdown]
# ## Time-varying composition of data

# %% [markdown]
# ### Stacked area plots

# %%
df_ = df[['mh', 'date', 'status']]

# %%
df_.head()

# %%
df_['mh'] = pd.to_numeric(df_['mh'])
df['date'] = pd.to_datetime(df_['date'])

# %% [markdown]
# ### pivot - is the way of reshaping data

# %%
df_ = df_.pivot_table(values = "mh", columns="status", index="date")

# %%
df_.head()

# %%
df_.plot.area(); # plot function of Pandas

# %%
plt.stackplot(df_.index, df_.Confirmed, df_.Recovered, df_.Deceased); # Matplotlib version of plot

# %% [markdown]
# ### Relative stacked area plot

# %%
fig = plt.gcf();
fig.set_size_inches(15,6);
plt.stackplot(df_.index, df_.Confirmed, df_.Recovered, df_.Deceased,
              colors = ['orange','green','red']);

# %%
fig = plt.gcf(); # entering the labels, and manually enter lengend function to display the same in the plot
fig.set_size_inches(15,6);
plt.stackplot(df_.index, df_.Confirmed, df_.Recovered, df_.Deceased,
              labels = ['Confirmed', 'Recovered', 'Deceased'],
              colors = ['orange','green','red']);
plt.legend();

# %%
# comparison of the data is difficult , so modify the code for better understanding
fig = plt.gcf();
fig.set_size_inches(15,6);
plt.stackplot(df_.index, df_.Confirmed/df_.sum(axis=1),
              df_.Recovered/df_.sum(axis=1),
              df_.Deceased/df_.sum(axis=1),
              labels = ['Confirmed', 'Recovered', 'Deceased'],
              colors = ['orange','green','red']);
plt.legend();

# %%
def plot_stacked_area_by_state(state):
    df_ = df[[state, 'date', 'status']]
    df_[state] = pd.to_numeric(df_[state])
    df['date'] = pd.to_datetime(df_['date'])
    df_ = df_.pivot_table(values = state, columns="status", index="date")
    fig = plt.gcf();
    fig.set_size_inches(15,6);
    plt.stackplot(df_.index, df_.Confirmed/df_.sum(axis=1),
                df_.Recovered/df_.sum(axis=1),
                df_.Deceased/df_.sum(axis=1),
                labels = ['Confirmed', 'Recovered', 'Deceased'],
                colors = ['orange','green','red']);
    plt.legend();

# %%
plot_stacked_area_by_state('tn') # plot for tamilnadu state, try for other states also

# %% [markdown]
# # Plotting relationships between data

# %% [markdown]
# ##Scatter plot

# %%
t = sns.load_dataset('tips')

# %%
t.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x='total_bill', y='tip', data=t);

# %%
t['tip_fraction'] = t['tip']/t['total_bill']

# %%
sns.scatterplot(x='total_bill', y='tip_fraction', data=t);

# %%
sns.scatterplot(x='total_bill', y='tip', data=t,
                hue='time');

# %%
sns.scatterplot(x='total_bill', y='tip', data=t,
                hue='sex');

# %%
sns.scatterplot(x='total_bill', y='tip', data=t,
                hue='smoker');

# %%
sns.scatterplot(x='total_bill', y='tip', data=t,
                hue='day');

# %%
sns.scatterplot(x='total_bill', y='tip', data=t,
                hue='size');

# %%
sns.scatterplot(x='total_bill', y='tip', data=t,
                hue='size', style = 'sex');

# %%
sns.scatterplot(x='total_bill', y='tip', data=t,
                hue='time',style = 'sex', size ='size'); # over lapping is ther in plot

# %%
sns.scatterplot(x='total_bill', y='tip', data=t,
                hue='time',style = 'sex', size ='size');
plt.legend(bbox_to_anchor=(1.05,1));

# %%
sns.regplot(x='total_bill', y='tip', data=t); # this plot shows the trend of the data

# %%
sns.regplot(x='total_bill', y='tip_fraction', data=t);

# %%
sns.regplot(x='total_bill', y='tip_fraction', data=t, marker ='+');

# %%
d = sns.load_dataset("diamonds")
d.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
# sns.scatterplot('x', data = d.sample(1000));
sns.scatterplot( x='x', y ='price',data=d.sample(1000));

# %%
sns.regplot(x='x', y ='price',data=d.sample(1000));

# %%
sns.regplot(x='x', y ='price',data=d.sample(1000), order = 2, marker='+');

# %% [markdown]
# ## Bar plots

# %% [markdown]
# for categorical variables - relationship between continuous variables and categorical variables

# %%
sns.barplot(x='day', y='tip', data=t);

# %%
sns.barplot(x='day', y='tip_fraction', data=t);

# %%
sns.barplot(x='day', y='tip', data=t, estimator=np.median);

# %%
def my_estimate(v):
    return np.quantile(v, 0.25)

# %%
# if you don't want mean or median, to give our own function
sns.barplot(x='day', y='tip', data=t, estimator=my_estimate);

# %%
sns.barplot(x='day', y='tip', hue="sex",data=t, estimator=np.median);

# %%
sns.barplot(x='day', y='tip', hue="time",data=t, estimator=np.median);
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# ## Continuous y and continuous x

# %%
d.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.scatterplot(x='x',y='price', data = d.sample(500));

# %%
sns.barplot(x='x',y='price', data = d.sample(500)); # not useful information in bar plot

# %% [markdown]
# pandas cut function here way to discretice
# continuous variable in pandas and concequent use in a bar plot to simplify such trends looking like above

# %%
d['x_q'] = pd.cut(d['x'],bins=15);
d.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#               x_q
# 0   (3.58, 4.296]
# 1   (3.58, 4.296]
# 2   (3.58, 4.296]
# 3   (3.58, 4.296]
# 4  (4.296, 5.012]

# %%
d['x_q'].unique()
# Out:
# [(3.069, 4.603], (4.603, 6.137], (6.137, 7.671], (-0.0107, 1.534], (7.671, 9.206], (9.206, 10.74]]
# Categories (7, interval[float64, right]): [(-0.0107, 1.534] < (1.534, 3.069] < (3.069, 4.603] <
#                                            (4.603, 6.137] < (6.137, 7.671] < (7.671, 9.206] <
#                                            (9.206, 10.74]]

# %%
sns.barplot(x='x_q',y='price', data = d.sample(1500));

# %%
d['x_q'] = pd.cut(d['x'],bins=15, labels=False);
d.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  x_q
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43    5
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31    5
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31    5
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63    5
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75    6

# %%
sns.barplot(x='x_q',y='price', data = d.sample(2500));

# %% [markdown]
# ## Line Plot

# %% [markdown]
# x plane continuous variable, y plane continuous variable values

# %%
f = sns.load_dataset('fmri')
f.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.lineplot(x='timepoint',y='signal',data=f)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(x='timepoint',y='signal',data=f,hue="region");

# %%
sns.lineplot(x='timepoint',y='signal',data=f,hue="event");

# %%
sns.lineplot(x='timepoint',y='signal',data=f,hue="event",style="region");

# %%
sns.lineplot(x='timepoint',y='signal',data=f,marker=True);

# %%
sns.lineplot(x='timepoint',y='signal',data=f,marker=True,estimator=np.median);

# %%
sns.lineplot(x='timepoint',y='signal',data=f,units="subject",estimator=None);

# %%
f_ = f[(f.region == "parietal")&(f.event == "cue")]
f_.head()
# Out:
#     subject  timepoint event    region    signal
# 532      s3          4   cue  parietal  0.058219
# 533      s6          5   cue  parietal  0.038145
# 534      s7          5   cue  parietal -0.008158
# 535      s8          5   cue  parietal  0.047136
# 536      s9          5   cue  parietal  0.055847

# %%
sns.lineplot(x='timepoint',y='signal',data=f_,units="subject",estimator=None);

# %%
sns.lineplot(x='timepoint',y='signal',data=f_,hue="subject",estimator=None);

# %%
x=np.array([-3,-2,-1,0,1,2,3])
y=x * x

# %%
sns.lineplot(x=x,y=y);

# %% [markdown]
# Linne plot for covid dataset,
# ordinary format to below
# date | state | confirmed value = format

# %%
df_ = pd.melt(df,id_vars="date",
              value_vars=list(df.columns).remove("date"),
              var_name="state",value_name="confirmed")
df_.head()

# %%
sns.lineplot(x='date',y='confirmed',data=df_);

# %%
sns.lineplot(x='date',y='confirmed',hue="state", data=df_);

# %%
states = ['mh','tn','dl','wb','ka','gj']
df_ = df_[df_.state.isin(states)]
df_.head()

# %%
# things are manageable now
sns.lineplot(x='date',y='confirmed',hue="state", data=df_);

# %%
sns.lineplot(x='date',y='confirmed',hue="state", data=df_,
             palette='Reds');

# %%
fig = plt.gcf();
fig.set_size_inches(15,6);
sns.lineplot(x='date',y='confirmed',hue="state", data=df_,
             palette='Reds');

# %%
fig = plt.gcf();
fig.set_size_inches(15,6);
sns.lineplot(x='date',y='confirmed',hue="state", data=df_,
             palette='Reds', hue_order=['wb','gj','ka','dl','tn','mh']);

# %% [markdown]
# ## Heat map

# %% [markdown]
# X [10 x 10]
# X(i,j) -> value

# %%
x = np.random.rand(10,10)

# %%
sns.heatmap(x)
# Out:
# <Axes: >

# %%
fl = sns.load_dataset('flights')
fl.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
fl.sample(10)
# Out:
#      year month  passengers
# 52   1953   May         229
# 99   1957   Apr         348
# 137  1960   Jun         535
# 46   1952   Nov         172
# 59   1953   Dec         201
# 76   1955   May         270
# 131  1959   Dec         405
# 48   1953   Jan         196
# 37   1952   Feb         180
# 0    1949   Jan         112

# %% [markdown]
# reshaping the data, pivot function
#
# 0	1949	Jan	112
#
# 1	1949	Feb	118
#
# 2	1949	Mar	132
#
# year Jan Feb March
#
# 1949 112 118 132

# %%
fl_ = fl.pivot(index='year',columns='month', values='passengers');
fl_.head()
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201

# %%
sns.heatmap(fl_);

# %%
sns.heatmap(fl_.T);

# %%
fig = plt.gcf();
fig.set_size_inches(15,8);
sns.heatmap(fl_.T,annot=True,fmt="d");

# %%
fig = plt.gcf();
fig.set_size_inches(15,8);
sns.heatmap(fl_.T,annot=True,fmt="d",cmap="YlGnBu");

# %% [markdown]
# we can crate our own color map

# %%
fig = plt.gcf();
fig.set_size_inches(15,8);
sns.heatmap(fl_.T,annot=True,fmt="d", cmap=sns.diverging_palette(250,10,n=10));

# %%
fig = plt.gcf();
fig.set_size_inches(15,8);
sns.heatmap(fl_.T,annot=True,fmt="d", cmap=sns.diverging_palette(25,150,n=50));

# %% [markdown]
# we can set the white coloe to particular value for smother look

# %%
fig = plt.gcf();
fig.set_size_inches(15,8);
sns.heatmap(fl_.T,annot=True,fmt="d", cmap=sns.diverging_palette(25,150,n=50),
            center=fl_.loc[1957,'Jul']);

# %% [markdown]
# # Task on open-ended visualisation

# %% [markdown]
# http://ml-india.org/datasets/
